# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],
                    columns=['col01','col02','col03'],
                    index=['idx01','idx02','idx03'])

# %%
data
# Out:
#        col01  col02  col03
# idx01      1      2      3
# idx02      4      5      6
# idx03      7      8      9

# %%
data_2 = pd.DataFrame(np.array([['A','B','C'],['D','E','F'],['G','H','K']]),
                               columns=['col01','col02','col03'],
                               index=['idx01','idx02','idx03'])

# %%
data_2
# Out:
#       col01 col02 col03
# idx01     A     B     C
# idx02     D     E     F
# idx03     G     H     K

# %%
data_2.index
# Out:
# Index(['idx01', 'idx02', 'idx03'], dtype='object')

# %%
data_2.columns
# Out:
# Index(['col01', 'col02', 'col03'], dtype='object')

# %%
data_3 = pd.DataFrame({'col01':[1,2,3],'col02':[4,5,6],
                       'col03':[7,8,9]})

# %%
data_3
# Out:
#    col01  col02  col03
# 0      1      4      7
# 1      2      5      8
# 2      3      6      9

# %%
data_3.index = ['idx001','idx002','idx003']

# %%
data_3
# Out:
#         col01  col02  col03
# idx001      1      4      7
# idx002      2      5      8
# idx003      3      6      9

# %%
data_3.columns = ['col_A','col_B','col_C']

# %%
data_3
# Out:
#         col_A  col_B  col_C
# idx001      1      4      7
# idx002      2      5      8
# idx003      3      6      9

# %%
data_3 = data_3.rename(columns={'col_A': 'col_X'})

# %%
data_3
# Out:
#         col_X  col_B  col_C
# idx001      1      4      7
# idx002      2      5      8
# idx003      3      6      9

# %%
data_3 = data_3.rename(columns={'col_B': 'col_Y', 'col_C': 'col_Z'})

# %%
data_3
# Out:
#         col_X  col_Y  col_Z
# idx001      1      4      7
# idx002      2      5      8
# idx003      3      6      9

# %%
data_3 = data_3.rename(index={'inx001':  'w'})

# %%
data_3
# Out:
#         col_X  col_Y  col_Z
# idx001      1      4      7
# idx002      2      5      8
# idx003      3      6      9

# %%
data_3['col_X']
# Out:
# idx001    1
# idx002    2
# idx003    3
# Name: col_X, dtype: int64

# %%
type(data_3['col_X'])
# Out:
# pandas.core.series.Series

# %%
data_3[['col_X']]
# Out:
#         col_X
# idx001      1
# idx002      2
# idx003      3

# %%
type(data_3[['col_X']])
# Out:
# pandas.core.frame.DataFrame

# %%
data_3.loc['idx001']
# Out:
# col_X    1
# col_Y    4
# col_Z    7
# Name: idx001, dtype: int64

# %%
data_3.loc['idx002', 'col_Y']
#data_3.loc['col_Y', 'idx002'
# Out:
# 5

# %%
data_3.loc[:, 'col_X']
# Out:
# idx001    1
# idx002    2
# idx003    3
# Name: col_X, dtype: int64

# %%
data_3
# Out:
#         col_X  col_Y  col_Z
# idx001      1      4      7
# idx002      2      5      8
# idx003      3      6      9

# %%
data_3.iloc[:, 0]
# Out:
# idx001    1
# idx002    2
# idx003    3
# Name: col_X, dtype: int64

# %%
data = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]],
                    columns=['col01','col02','col03'],
                    index=['idx01','idx02','idx03'])

# %%
data
# Out:
#        col01  col02  col03
# idx01      1      2      3
# idx02      4      5      6
# idx03      7      8      9

# %%
data.loc['idx03','col02']=80
data
# Out:
#        col01  col02  col03
# idx01      1      2      3
# idx02      4      5      6
# idx03      7     80      9

# %%
data.loc[:, 'col03']=['Tokyo','Kyoto','Fukuoka']

# %%
data
# Out:
#        col01  col02    col03
# idx01      1      2    Tokyo
# idx02      4      5    Kyoto
# idx03      7     80  Fukuoka

# %%
data.loc[:,'col02':'col03']
# Out:
#        col02    col03
# idx01      2    Tokyo
# idx02      5    Kyoto
# idx03     80  Fukuoka

# %%
data.iloc[:, 1:3]
# Out:
#        col02    col03
# idx01      2    Tokyo
# idx02      5    Kyoto
# idx03     80  Fukuoka

# %%
data.index.get_loc('idx02')
# Out:
# 1

# %%
data.columns.get_loc('col03')
# Out:
# 2

# %%
data.dtypes
# Out:
# col01     int64
# col02     int64
# col03    object
# dtype: object

# %%
data.shape
# Out:
# (3, 3)
